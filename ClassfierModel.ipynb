# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df_x = df.iloc[:,3:-1]

# %%
df_x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
df_y = df.iloc[:, -1:]

# %%
df_y
# Out:
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 1 columns]

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df_x['Gender']= label_encoder.fit_transform(df['Gender'])

# %%
df_x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
df_x = pd.get_dummies(df_x, columns = ['Geography'])
print(one_hot_encoded_data)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7       0.00              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88                 1                  0
# 1                  1        112542.58                 0                  0
# 2                  0        113931.57                 1                  0
# 3                  0         93826.63                 1                  0
# 4                  1         79084.10                 0                  0
# ...              ...              ...               ...                ...
# 9995               0         96270.64                 1                  0
# 9996               1        101699.77                 1                  0
# 9997               1         42085.58                 1                  0
# 9998               0         92888.52                 0                  1
# 9999               0         38190.78                 1                  0
#
#       Geography_Spain
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 12 columns]

# %%
df_x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7       0.00              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88                 1                  0
# 1                  1        112542.58                 0                  0
# 2                  0        113931.57                 1                  0
# 3                  0         93826.63                 1                  0
# 4                  1         79084.10                 0                  0
# ...              ...              ...               ...                ...
# 9995               0         96270.64                 1                  0
# 9996               1        101699.77                 1                  0
# 9997               1         42085.58                 1                  0
# 9998               0         92888.52                 0                  1
# 9999               0         38190.78                 1                  0
#
#       Geography_Spain
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = preprocessing.StandardScaler()
standard_df = scaler.fit_transform(df_x)

# %%
standard_df
# Out:
# array([[-0.32622142, -1.09598752,  0.29351742, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        [-0.44003595, -1.09598752,  0.19816383, ..., -1.00280393,
#         -0.57873591,  1.74273971],
#        [-1.53679418, -1.09598752,  0.29351742, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        ...,
#        [ 0.60498839, -1.09598752, -0.27860412, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        [ 1.25683526,  0.91241915,  0.29351742, ..., -1.00280393,
#          1.72790383, -0.57380915],
#        [ 1.46377078, -1.09598752, -1.04143285, ...,  0.99720391,
#         -0.57873591, -0.57380915]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(standard_df, df_y, test_size=0.05, random_state=0)

# %%
from sklearn import linear_model, metrics

# create logistic regression object
reg = linear_model.LogisticRegression()

# train the model using the training sets
reg.fit(X_train, y_train)

# making predictions on the testing set
y_pred = reg.predict(X_test)

# comparing actual response values (y_test) with predicted response values (y_pred)
print("Logistic Regression model accuracy(in %):",
metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Logistic Regression model accuracy(in %): 82.8
# C:\Users\Bhakti\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test,y_pred)
print(conf_mat)
# Out:
# [[388  13]
#  [ 73  26]]

# %%
from sklearn import linear_model, metrics
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB

# create logistic regression object
gnb = GaussianNB()

# train the model using the training sets
gnb.fit(X_train, y_train)

# making predictions on the testing set
y_pred1 = gnb.predict(X_test)

# comparing actual response values (y_test) with predicted response values (y_pred)
print("Logistic Regression model accuracy(in %):",
metrics.accuracy_score(y_test, y_pred1)*100)

conf_mat1 = confusion_matrix(y_test,y_pred1)
print(conf_mat1)
# Out:
# Logistic Regression model accuracy(in %): 84.39999999999999
# [[374  27]
#  [ 51  48]]
# C:\Users\Bhakti\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn import linear_model, metrics
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier(n_neighbors=1)


knn.fit(X_train, y_train)


y_pred2 = knn.predict(X_test)


print("Logistic Regression model accuracy(in %):",
metrics.accuracy_score(y_test, y_pred2)*100)

conf_mat2 = confusion_matrix(y_test,y_pred2)

print(conf_mat2)
# Out:
# Logistic Regression model accuracy(in %): 80.60000000000001
# [[344  57]
#  [ 40  59]]
# C:\Users\Bhakti\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn import linear_model, metrics
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC


svc_model = SVC(C= .1, kernel='linear', gamma= 1)

svc_model.fit(X_train, y_train)

y_pred3 = svc_model.predict(X_test)

print("Logistic Regression model accuracy(in %):",
metrics.accuracy_score(y_test, y_pred3)*100)

conf_mat3 = confusion_matrix(y_test,y_pred3)

print(conf_mat3)
# Out:
# C:\Users\Bhakti\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression model accuracy(in %): 80.2
# [[401   0]
#  [ 99   0]]

# %%
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
iris = datasets.load_iris()

# %%
X = iris.data[:, :2]
y = iris.target
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.80, test_size=0.20, random_state=101)

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# %%
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)

# %%
poly_pred
# Out:
# array([0, 0, 0, 2, 2, 1, 1, 1, 1, 0, 2, 0, 0, 2, 1, 2, 1, 1, 0, 1, 1, 0,
#        1, 2, 1, 1, 1, 1, 0, 1])
